# %%
#importing necessary libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\baseball.csv")
df
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
df.tail(5)
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 25  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6   21
# 26  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7   18
# 27  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1   12
# 28  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1    6
# 29  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4    4
#
#     SV   E   W
# 25  47  75  92
# 26  41  78  84
# 27  44  86  79
# 28  41  92  74
# 29  36  95  68

# %%
df.head(15)
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
# ...

# %%
df.sample()
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9
#
#     SV    E   W
# 10  45  119  88

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
df.shape
# Out:
# (30, 17)

# %%
df.columns
# Out:
# Index(['R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'E', 'W'],
#       dtype='object')

# %%
df.dtypes
# Out:
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# W        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# W      0
# dtype: int64

# %% [markdown]
# There are no null values in any of the columns, so no need of treating null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   R       30 non-null     int64
#  1   AB      30 non-null     int64
#  2   H       30 non-null     int64
#  3   2B      30 non-null     int64
#  4   3B      30 non-null     int64
#  5   HR      30 non-null     int64
#  6   BB      30 non-null     int64
#  7   SO      30 non-null     int64
#  8   SB      30 non-null     int64
#  9   RA      30 non-null     int64
#  10  ER      30 non-null     int64
#  11  ERA     30 non-null     float64
#  12  CG      30 non-null     int64
#  13  SHO     30 non-null     int64
#  14  SV      30 non-null     int64
#  15  E       30 non-null     int64
#  16  W       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# from heatmap it is clear that there is no null values

# %%
for i in df.columns:
    print(df[i].unique())
    print('\n')
    print(df[i].nunique())
    print('\n')
# Out:
# [724 696 669 622 689 891 764 713 644 748 751 729 661 656 694 647 697 655
#  640 683 703 613 573 626 667 720 650 737]
#
#
# 28
#
#
# [5575 5467 5439 5533 5605 5509 5567 5485 5640 5511 5459 5417 5544 5600
#  5484 5631 5491 5480 5571 5527 5428 5463 5420 5529 5385 5565 5649 5457
#  5572]
#
#
# 29
#
#
# [1497 1349 1395 1381 1515 1480 1397 1370 1383 1495 1419 1363 1331 1379
#  1405 1386 1462 1341 1378 1382 1351 1420 1361 1374 1346 1486 1494 1324
#  1479]
#
#
# 29
#
#
# [300 277 303 260 289 308 272 246 278 294 279 243 262 288 292 274 257 295
#  265 236 251 263]
#
#
# 22
#
#
# [42 44 29 27 49 17 19 20 32 33 26 21 22 46 39 30 34 13 40 18 37 48 36]
#
#
# 23
#
#
# [139 156 141 136 151 232 212 217 167 161 172 230 176 198 146 137 140 171
#  145 177 120 100 130 187 154 148 186]
#
#
# 27
#
#
# [383 439 533 404 455 570 554 418 436 478 503 486 435 475 506 461 567 412
#  496 488 539 375 471 387 563 457 490 426 388]
#
#
# 29
#
#
# [ 973 1264 1157 1231 1259 1151 1227 1331 1310 1148 1233 1392 1150 1336
# ...

# %%
df.nunique().to_frame("No. of unique values")
# Out:
#      No. of unique values
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21
# W                      24

# %% [markdown]
# # Description of dataset

# %%
df.describe()
# Out:
#                 R           AB            H          2B         3B  \
# count   30.000000    30.000000    30.000000   30.000000  30.000000
# mean   688.233333  5516.266667  1403.533333  274.733333  31.300000
# std     58.761754    70.467372    57.140923   18.095405  10.452355
# min    573.000000  5385.000000  1324.000000  236.000000  13.000000
# 25%    651.250000  5464.000000  1363.000000  262.250000  23.000000
# 50%    689.000000  5510.000000  1382.500000  275.500000  31.000000
# 75%    718.250000  5570.000000  1451.500000  288.750000  39.000000
# max    891.000000  5649.000000  1515.000000  308.000000  49.000000
#
#                HR          BB          SO          SB          RA          ER  \
# count   30.000000   30.000000    30.00000   30.000000   30.000000   30.000000
# mean   163.633333  469.100000  1248.20000   83.500000  688.233333  635.833333
# std     31.823309   57.053725   103.75947   22.815225   72.108005   70.140786
# ...

# %% [markdown]
# The statisctical description is given in the above table. From mean and 50th percentile(median) we can infer about the skewness of the columns, if mean < median --> negative skewness, otherwise positively skewed. The 75th quantile and the max value can be used to infer about the outliers present in the dataset ,which needs to be treated appropriately before building the model.

# %% [markdown]
# Also we can notice that there is high standard deviation, in most of the columns.

# %% [markdown]
# # Visualisation of dataset

# %%
#bivariant analysis
sns.scatterplot(x='R',data=df, y = 'H')
# Out:
# <Axes: xlabel='R', ylabel='H'>

# %%
sns.scatterplot(x='2B',data=df, y = '3B')
# Out:
# <Axes: xlabel='2B', ylabel='3B'>

# %%
sns.scatterplot(x='SO',data=df, y = 'SB')
# Out:
# <Axes: xlabel='SO', ylabel='SB'>

# %%
sns.scatterplot(x='RA',data=df, y = 'ER')
# Out:
# <Axes: xlabel='RA', ylabel='ER'>

# %% [markdown]
# The above graph shows that the columns RA and ER tend to be directly proportional with each other

# %%
sns.lineplot(x='H',data=df, y = 'AB')
# Out:
# <Axes: xlabel='H', ylabel='AB'>

# %% [markdown]
# Although there is a direct proportionality between H and AB , there are also some spikes going up and down showing no strong direct proportionality

# %%
sns.lineplot(x='BB',data=df, y = 'W')
# Out:
# <Axes: xlabel='BB', ylabel='W'>

# %%
sns.lineplot(x="SHO",data=df, y='ERA')
# Out:
# <Axes: xlabel='SHO', ylabel='ERA'>

# %% [markdown]
# There is a gradual decrease in value of SHO as ERA increase but there are also some spikes found.

# %%
sns.catplot(x="SV",y="E",data=df, kind='bar')

# %% [markdown]
# From the above graph, at the moment we can infer that there is no such evident relation betweeen SV and E columns as there are are up and down spikes.

# %%
#univariant analysis
sns.violinplot(x="AB",data=df)
# Out:
# <Axes: xlabel='AB'>

# %%
sns.violinplot(x="R",data=df)
# Out:
# <Axes: xlabel='R'>

# %%
sns.violinplot(x="CG",data=df)
# Out:
# <Axes: xlabel='CG'>

# %%
sns.lineplot(x='BB',data=df, y = 'HR')
# Out:
# <Axes: xlabel='BB', ylabel='HR'>

# %%
sns.pairplot(df, palette = "Dark2")
plt.show()

# %%
plt.figure(figsize=(20,25))
p=1
for i in df:
    if p<=20:
        plt.subplot(5,4,p)
        sns.histplot(df[i], bins=10, kde=True, palette='Set2_r')
        plt.xlabel(i)
        
    p+=1
    
plt.show()

# %% [markdown]
# # Checking duplicates

# %%
duplicates_exist = df.duplicated().any()


if duplicates_exist:
    print("There are duplicates in the dataset.")
else:
    print("There are no duplicates in the dataset.")
# Out:
# There are no duplicates in the dataset.

# %% [markdown]
# # Checking outliers using boxplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 25))
p = 1

for i in df.columns:
    if p <= 12:
        plt.subplot(4, 3, p)

        if df[i].dtype in ['float64', 'int64']:
            sns.boxplot(df[i], palette='Set2_r')
            plt.xlabel(i)
    p += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# We could see some outliers in columns R and ERA, lets further inspect using zscore

# %%
from scipy.stats import zscore 
out_features = df[['R', 'ERA']]
z=np.abs(zscore(out_features))
z
# Out:
#            R       ERA
# 0   0.619078  0.506955
# 1   0.134432  0.254598
# 2   0.332906  0.641347
# 3   1.146419  0.053010
# 4   0.013270  1.531318
# 5   3.509647  0.350165
# 6   1.311430  0.165003
# 7   0.428681  0.209800
# 8   0.765626  0.484557
# 9   1.034489  0.792164
# 10  1.086415  0.635374
# 11  0.705622  0.865333
# 12  0.471376  0.036584
# 13  0.557920  0.456185
# 14  0.099814  0.411388
# 15  0.713699  2.276445
# 16  0.151740  1.671683
# 17  0.013270  1.335704
# 18  0.575229  0.724968
# 19  0.834861  0.836961
# 20  0.090583  1.178913
# 21  0.255593  0.753340
# 22  1.302198  0.142604
# 23  1.994550  1.016150
# 24  1.077184  1.643311
# 25  0.367523  1.156515
# 26  0.134432  0.529354
# 27  0.549843  0.187402
# 28  0.661773  0.299395
# 29  0.844092  2.427263

# %%
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
z.iloc[5,0]
# Out:
# 3.5096470447193067

# %% [markdown]
# Only one data has z- score more than 3, so decided to keep them.

# %% [markdown]
# # checking for skewness

# %%
df.skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# W      0.047089
# dtype: float64

# %% [markdown]
# Normally values close to -0.52 to +0.52 are acceptable for skewness, the columns with values way more than that need to be treated using appropriate methods, lets do that.
# So columns R,CG,E,SHO, SV needs to be treated.

# %%
df['H'] = np.log1p(df['H'])
df['R'] = np.log1p(df['R'])
df['CG'] = np.log1p(df['CG'])
df['E'] = np.log1p(df['E'])
df['SHO'] = np.log1p(df['SHO'])
df['SV'] = np.log1p(df['SV'])

# %%
df.skew()
# Out:
# R      0.744813
# AB     0.183437
# H      0.628584
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.325962
# SHO   -0.589640
# SV     0.163057
# E      0.632916
# W      0.047089
# dtype: float64

# %%
sns.histplot(df['W'])
# Out:
# <Axes: xlabel='W', ylabel='Count'>

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
    
df
# Out:
#            R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   6.586172  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1   6.546785  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2   6.507278  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3   6.434547  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4   6.536692  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
# 5   6.793466  5509  7.300473  308  17  232  570  1151   88  670  609  3.80
# 6   6.639876  5567  7.242798  272  19  212  554  1227   63  698  652  4.03
# 7   6.570883  5485  7.223296  246  20  217  418  1331   44  693  646  4.05
# 8   6.469250  5485  7.232733  278  32  167  436  1310   87  642  604  3.74
# 9   6.618739  5640  7.310550  294  33  161  478  1148   71  753  694  4.31
# 10  6.622736  5511  7.258412  279  32  172  503  1233  101  733  680  4.24
# ...

# %%
df.dtypes
# Out:
# R      float64
# AB       int64
# H      float64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG     float64
# SHO    float64
# SV     float64
# E      float64
# W        int64
# dtype: object

# %% [markdown]
# # checking correlation

# %%
cor = df.corr()
cor
# Out:
#             R        AB         H        2B        3B        HR        BB  \
# R    1.000000  0.338137  0.481814  0.566754 -0.045152  0.676421  0.395835
# AB   0.338137  1.000000  0.740101  0.453370  0.435422 -0.066983 -0.136414
# H    0.481814  0.740101  1.000000  0.566231  0.476582 -0.091319 -0.117854
# 2B   0.566754  0.453370  0.566231  1.000000  0.220490  0.056292  0.302700
# 3B  -0.045152  0.435422  0.476582  0.220490  1.000000 -0.430915 -0.454949
# HR   0.676421 -0.066983 -0.091319  0.056292 -0.430915  1.000000  0.425691
# BB   0.395835 -0.136414 -0.117854  0.302700 -0.454949  0.425691  1.000000
# SO  -0.030676 -0.106022 -0.400196 -0.150752 -0.141196  0.359923  0.233652
# SB   0.081068  0.372618  0.415694  0.195027  0.457437 -0.136567 -0.098347
# RA  -0.051780  0.316010  0.223397 -0.218160  0.314125 -0.103903 -0.416445
# ER  -0.049372  0.309686  0.251906 -0.235531  0.340225 -0.085922 -0.452663
# ERA -0.058923  0.255551  0.230628 -0.254854  0.330951 -0.090917 -0.459832
# ...

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(df.corr(), annot = True, fmt = ".1g")
plt.show()

# %%
cor['W'].sort_values(ascending = False)
# Out:
# W      1.000000
# SV     0.668097
# BB     0.484342
# R      0.442808
# SHO    0.436247
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.047176
# H      0.035307
# AB    -0.087947
# E     -0.090225
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %%
cor['W'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# Since features ER, RA, ERA has high negative correlation with target variable, it is evident to drop them as they are negatively related with our target variable.

# %%
df = df.drop(["ER","RA","ERA"], axis=1)
df
# Out:
#            R    AB         H   2B  3B   HR   BB    SO   SB        CG  \
# 0   6.586172  5575  7.311886  300  42  139  383   973  104  1.098612
# 1   6.546785  5467  7.207860  277  44  156  439  1264   70  1.098612
# 2   6.507278  5439  7.241366  303  29  141  533  1157   86  2.484907
# 3   6.434547  5533  7.231287  260  27  136  404  1231   68  2.079442
# 4   6.536692  5605  7.323831  289  49  151  455  1259   83  2.079442
# 5   6.793466  5509  7.300473  308  17  232  570  1151   88  2.079442
# 6   6.639876  5567  7.242798  272  19  212  554  1227   63  1.386294
# 7   6.570883  5485  7.223296  246  20  217  418  1331   44  0.000000
# 8   6.469250  5485  7.232733  278  32  167  436  1310   87  0.693147
# 9   6.618739  5640  7.310550  294  33  161  478  1148   71  1.386294
# 10  6.622736  5511  7.258412  279  32  172  503  1233  101  1.791759
# 11  6.593045  5459  7.218177  278  26  230  486  1392  121  1.791759
# 12  6.495266  5417  7.194437  243  21  176  435  1150   52  1.098612
# ...

# %%
cor = df.corr()
cor
# Out:
#             R        AB         H        2B        3B        HR        BB  \
# R    1.000000  0.338137  0.481814  0.566754 -0.045152  0.676421  0.395835
# AB   0.338137  1.000000  0.740101  0.453370  0.435422 -0.066983 -0.136414
# H    0.481814  0.740101  1.000000  0.566231  0.476582 -0.091319 -0.117854
# 2B   0.566754  0.453370  0.566231  1.000000  0.220490  0.056292  0.302700
# 3B  -0.045152  0.435422  0.476582  0.220490  1.000000 -0.430915 -0.454949
# HR   0.676421 -0.066983 -0.091319  0.056292 -0.430915  1.000000  0.425691
# BB   0.395835 -0.136414 -0.117854  0.302700 -0.454949  0.425691  1.000000
# SO  -0.030676 -0.106022 -0.400196 -0.150752 -0.141196  0.359923  0.233652
# SB   0.081068  0.372618  0.415694  0.195027  0.457437 -0.136567 -0.098347
# CG   0.257477 -0.059218  0.113814  0.282895 -0.058674  0.200279  0.484686
# SHO -0.122232 -0.189223 -0.125939  0.073459 -0.064669 -0.068809  0.362907
# SV  -0.075357 -0.133599 -0.152503  0.144282 -0.184189 -0.005146  0.110550
# ...

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(df.corr(), annot = True, fmt = ".1g")
plt.show()

# %%
cor['W'].sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Seperating feautures and target column

# %%
df
# Out:
#            R    AB         H   2B  3B   HR   BB    SO   SB        CG  \
# 0   6.586172  5575  7.311886  300  42  139  383   973  104  1.098612
# 1   6.546785  5467  7.207860  277  44  156  439  1264   70  1.098612
# 2   6.507278  5439  7.241366  303  29  141  533  1157   86  2.484907
# 3   6.434547  5533  7.231287  260  27  136  404  1231   68  2.079442
# 4   6.536692  5605  7.323831  289  49  151  455  1259   83  2.079442
# 5   6.793466  5509  7.300473  308  17  232  570  1151   88  2.079442
# 6   6.639876  5567  7.242798  272  19  212  554  1227   63  1.386294
# 7   6.570883  5485  7.223296  246  20  217  418  1331   44  0.000000
# 8   6.469250  5485  7.232733  278  32  167  436  1310   87  0.693147
# 9   6.618739  5640  7.310550  294  33  161  478  1148   71  1.386294
# 10  6.622736  5511  7.258412  279  32  172  503  1233  101  1.791759
# 11  6.593045  5459  7.218177  278  26  230  486  1392  121  1.791759
# 12  6.495266  5417  7.194437  243  21  176  435  1150   52  1.098612
# ...

# %%
df.shape
# Out:
# (30, 14)

# %%
x= df.drop("W", axis=1)
y=df['W']

# %%
x.shape
# Out:
# (30, 13)

# %%
y.shape
# Out:
# (30,)

# %% [markdown]
# # Feature Scaling and standardisation

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.665329  0.847731  1.649382  1.420173  1.041193 -0.787299 -1.534902
# 1   0.179562 -0.711094 -0.981656  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.307704 -1.115233 -0.134210  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.204730  0.241522 -0.389136 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.055070  1.280738  1.951480  0.801892  1.722347 -0.403770 -0.251360
# 5   3.221983 -0.104884  1.360715  1.869832 -1.391501  2.185047  1.798742
# 6   1.327687  0.732263 -0.098001 -0.153633 -1.196885  1.545833  1.513510
# 7   0.476767 -0.451289 -0.591253 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.776713 -0.451289 -0.352560  0.183611  0.068115  0.107601 -0.590073
# 9   1.066997  1.785913  1.615591  1.082929  0.165423 -0.084163  0.158660
# 10  1.116298 -0.076017  0.296915  0.239818  0.068115  0.267405  0.604334
# 11  0.750096 -0.826562 -0.720719  0.183611 -0.515731  2.121125  0.301276
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values'] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features'] = x.columns
vif
# Out:
#     VIF values Features
# 0     9.183095        R
# 1     3.906797       AB
# 2     6.815556        H
# 3     3.008357       2B
# 4     2.619943       3B
# 5     7.440829       HR
# 6     3.275358       BB
# 7     2.200877       SO
# 8     1.586956       SB
# 9     2.259331       CG
# 10    1.458809      SHO
# 11    1.661171       SV
# 12    1.953854        E

# %% [markdown]
# # Modelling

# %% [markdown]
# Finding the best random state

# %%
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_absolute_error 
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import r2_score 
from sklearn.ensemble import GradientBoostingRegressor 
from sklearn.linear_model import LinearRegression

# %%
max_acc = 0
rs = 0
for i in range(1,200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = i)
    LR  = LinearRegression()
    LR.fit(x_train, y_train)
    pred = LR.predict(x_test)
    accuracy = r2_score(y_test, pred)
    if accuracy>max_acc:
        max_acc = accuracy
        rs = i
        
print("Best accuracy is", max_acc,"at random state", rs)
# Out:
# Best accuracy is 0.8224445941702201 at random state 1

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = rs)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor 
from sklearn.neighbors import KNeighborsRegressor as KNN 
from sklearn.linear_model import Lasso, Ridge

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train= LR.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_LR))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_LR))
print('mean_squared_error is', mean_squared_error(y_test, pred_LR))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# r2_score is  0.8224445941702201
# r2_score of training is  0.845014602238009
# mean_absolute_error is 3.458804017960076
# mean_squared_error is 23.231261617086503
# root_mean_squared_error is 4.819881909039526

# %%
plt.scatter(x=pred_LR, y=y_test, color='r')
plt.plot(pred_LR, pred_LR, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train= RFR.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_RFR))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_RFR))
print('mean_squared_error is', mean_squared_error(y_test, pred_RFR))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# r2_score is  0.6097557369314967
# r2_score of training is  0.8843663617737451
# mean_absolute_error is 5.809999999999999
# mean_squared_error is 51.05936666666665
# root_mean_squared_error is 7.145583717700511

# %%
knn=KNN()
knn.fit(x_train, y_train)
pred_knn = knn.predict(x_test)
pred_train= knn.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_knn))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_knn))
print('mean_squared_error is', mean_squared_error(y_test, pred_knn))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_knn)))
# Out:
# r2_score is  0.45738441215323655
# r2_score of training is  0.45167861846919355
# mean_absolute_error is 7.466666666666667
# mean_squared_error is 70.99555555555554
# root_mean_squared_error is 8.425886039791633

# %%
lasso=Lasso()
lasso.fit(x_train, y_train)
pred_lasso = lasso.predict(x_test)
pred_train= lasso.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_lasso))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_lasso))
print('mean_squared_error is', mean_squared_error(y_test, pred_lasso))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_lasso)))
# Out:
# r2_score is  0.8641515754002929
# r2_score of training is  0.7503874913273125
# mean_absolute_error is 3.4598910174803432
# mean_squared_error is 17.7743407889839
# root_mean_squared_error is 4.215962617123626

# %%
plt.scatter(x=pred_lasso, y=y_test, color='r')
plt.plot(pred_lasso, pred_lasso, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
ridge=Ridge()
ridge.fit(x_train, y_train)
pred_ridge = ridge.predict(x_test)
pred_train= ridge.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_ridge))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_ridge))
print('mean_squared_error is', mean_squared_error(y_test, pred_ridge))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_ridge)))
# Out:
# r2_score is  0.7563776194502589
# r2_score of training is  0.8373573271430728
# mean_absolute_error is 3.9259208512189208
# mean_squared_error is 31.875431963779704
# root_mean_squared_error is 5.645833150543833

# %%
plt.scatter(x=pred_ridge, y=y_test, color='r')
plt.plot(pred_ridge, pred_ridge, color='b')
plt.xlabel('actual')
plt.ylabel('predicted')
plt.show()

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(x_train, y_train)
pred_ETR = ETR.predict(x_test)
pred_train= ETR.predict(x_train)
print('r2_score is ',r2_score(y_test, pred_ETR))
print('r2_score of training is ',r2_score(y_train, pred_train))
print('mean_absolute_error is', mean_absolute_error(y_test, pred_ETR))
print('mean_squared_error is', mean_squared_error(y_test, pred_ETR))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred_ETR)))
# Out:
# r2_score is  0.6034282223060956
# r2_score of training is  1.0
# mean_absolute_error is 6.252222222222222
# mean_squared_error is 51.88725555555554
# root_mean_squared_error is 7.203280888286638

# %% [markdown]
# # cross val score

# %%
from sklearn.model_selection import cross_val_score

score = cross_val_score(LR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_LR)-score.mean())
# Out:
# [ 0.03035577 -2.48207365  0.07302812  0.38575634  0.71630815]
# -0.25532505346698703
# Difference is 1.0777696476372072

# %%
score = cross_val_score(RFR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_RFR)-score.mean())
# Out:
# [-0.24543028 -1.3964916  -0.1236428   0.24932484  0.52497716]
# -0.19825253901178613
# Difference is 0.8080082759432827

# %%
score = cross_val_score(knn,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_knn)-score.mean())
# Out:
# [ 0.00472469 -0.87282443 -0.25593298  0.2402135   0.41775148]
# -0.09321354723080726
# Difference is 0.5505979593840438

# %%
score = cross_val_score(lasso,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_lasso)-score.mean())
# Out:
# [ 0.51871377 -1.189014    0.41049423  0.47789814  0.73835739]
# 0.19128990471992677
# Difference is 0.6728616706803661

# %%
score = cross_val_score(ETR,x,y, cv=5, scoring='r2')
print(score)
print(score.mean())
print("Difference is", r2_score(y_test,pred_ETR)-score.mean())
# Out:
# [-0.16381137 -2.4671687   0.16923968  0.25604484  0.56622024]
# -0.3278950635980336
# Difference is 0.9313232859041292

# %% [markdown]
# KNN has least difference and is selected as the best fitting model.

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

param = {
    'alpha': [0.01, 0.1, 1, 10, 100],
    'fit_intercept': [True, False],
    'max_iter': [1000, 2000, 3000],
}

estimator = Lasso()

gscv = GridSearchCV(estimator, param, cv=5)

# %%
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [0.01, 0.1, 1, 10, 100],
#                          'fit_intercept': [True, False],
#                          'max_iter': [1000, 2000, 3000]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1, 'fit_intercept': True, 'max_iter': 1000}

# %%
Model=Lasso(alpha=1, fit_intercept=True, max_iter=1000)

# %%
Model.fit(x_train, y_train)
pred = Model.predict(x_test)
print('r2_score is ',r2_score(y_test, pred))
print('mean_absolute_error is', mean_absolute_error(y_test, pred))
print('mean_squared_error is', mean_squared_error(y_test, pred))
print('root_mean_squared_error is', np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# r2_score is  0.8641515754002929
# mean_absolute_error is 3.4598910174803432
# mean_squared_error is 17.7743407889839
# root_mean_squared_error is 4.215962617123626

# %%
#saving model 
import pickle 
filename='baseball_case_study.pkl'
pickle.dump(Model, open(filename,'wb'))

# %%
import pickle 
loaded_model = pickle.load(open('baseball_case_study.pkl', 'rb'))
res = loaded_model.score(x_test, y_test)
print(res*100)
# Out:
# 86.41515754002928

# %%
final = pd.DataFrame([loaded_model.predict(x_test)[:], y_test[:]], index=['predicted','original'])
final
# Out:
#                    0          1         2          3          4          5  \
# predicted  90.612561  83.583861  86.71149  70.669554  72.011339  87.644487
# original   97.000000  83.000000  88.00000  64.000000  68.000000  90.000000
#
#                    6          7          8
# predicted  83.988544  69.918462  66.749809
# original   84.000000  76.000000  63.000000

# %% [markdown]
# Initially, i have tried removing that particular data which has z-score more than 3,keeping the 3 columns which has very high negative correlation with target variable, but in both the cases the model's prediction % i.e, r2 score is less than the above.

# %% [markdown]
# Closing up, my model did a decent job predicting how many games a baseball team would win in 2015, hitting an 86.41% accuracy. Using 16 different things that show how well a team is doing, the model gives a good estimate of their success. It's not just about baseball stats; it's like having a crystal ball for future games. This project shows how digging into past data can really help us see what might happen next in the world of baseball.
